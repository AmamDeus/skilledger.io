# %% [markdown]
# # GRANT ACQUISITION ANALYSIS

# %% [markdown]
# ## The value propositions of the grant model are:
# 1. To increase research revenue in Lagos Business School through grant acquisition
# 2. To reduce the risk of grant application failure and minimise effort of application.

# %%
import pandas as pd

# %%
grant = pd.read_csv("LBS_Grant.csv")

# %%
grant
# Out:
#     GrantID                                            Grantor  \
# 0         1                       Sunref Nigeria & Access bank
# 1         2  Ford Foundation and Innocent Chukwuma Social I...
# 2         3                                    Ford Foundation
# 3         4                       Templeton Charity Foundation
# 4         5                                               Meta
# 5         6                                   Bank of Industry
# 6         7                 Aspire Coronation Trust Foundation
# 7         8                                    BRAC University
# 8         9                                               SAMS
# 9        10                                               CIPE
# 10       11          Mastercard Foundation and Caribou Digital
# 11       12                  International Labour Organisation
# 12       13                         Digital Credit Observatory
# 13       14                                   Fairwork project
# 14       15                        Gamaliel Onosode Foundation
# 15       16               Belinda and Melinda Gates Foundation
# 16       17                                      Anglia Ruskin
# 17       18                                                UCL
# 18       19                                                UCL
# 19       20                                      Anglia Ruskin
# 20       21                                                UCL
# 21       22                                              SUDOC
# 22       23                                   Goethe Institute
# 23       24                 Institute de Hautes Etudes Afrique
# 24       25                                   Goethe Institute
# 25       26                                   Goethe Institute
# 26       27                                          Coca-Cola
# 27       28                                Research department
# 28       29                                Research department
# 29       30          Chartered Institute of Banking in Nigeria
# 30       31                                      Fidelity Bank
# 31       32                                Research department
# 32       33                                Research department
# 33       34                                     European Union
# 34       35                                               GCRF
# 35       36                                              Oxfam
# 36       37                                 Spencer Foundation
# 37       38                            Tony Elumelu Foundation
# 38       39                                                 na
# 39       40                               University of Surrey
# 40       41                              Women's World Banking
# 41       42                                    Ford foundation
# 42       43                                               SAMS
# 43       44                                Horowitz Foundation
# 44       45                   National Endowment for Democracy
# 45       46                                 Urgent Fund-Africa
# 46       47                            The Elsevier Foundation
# 47       48                                      Wellcome Trus
# 48       49                         The Social Venture Network
# 49       50                  West African Research Association
# 50       51                                        Common Fund
#
#                       Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  \
# 0                        energy    2022      312623.20         3.0
# 1                sustainability    2021     1000000.12         5.0
# 2                sustainability    2017       25400.45         5.0
# 3               virtual reality    2021      234000.12         5.0
# 4               virtual reality    2022      500000.45         5.0
# 5              entrepreneurship    2022     1184834.23         5.0
# 6                sustainability    2021       71000.00         5.0
# 7   digital financial inclusion    2022            NaN         1.0
# 8                      academia    2022            NaN         1.0
# 9               business ethics    2021            NaN         1.0
# 10            women empowerment    2022       40199.12         1.0
# 11            women empowerment    2021            NaN         1.0
# 12            women empowerment    2022       54471.15         1.0
# 13  digital financial inclusion    2022       25764.56         1.0
# 14                     research    2018     1184834.44        10.0
# 15  digital financial inclusion    2017     6904650.56         6.0
# 16                       energy    2021        7693.21         1.0
# 17                       energy    2021       10977.37         1.0
# 18                       energy    2021       17881.88         2.0
# 19                       energy    2021        1930.00         1.0
# 20                       energy    2021       10977.21         2.0
# 21                     research    2021       10000.01         2.0
# 22                          art    2021        1826.01         1.0
# 23                          art    2021        7302.01         1.0
# 24                          art    2022        4810.02         1.0
# 25                          art    2022         609.11         1.0
# 26               sustainability    2016        9500.04         5.0
# 27                    Marketing    2017      161325.33         1.0
# 28                     Strategy    2018          70.12         1.0
# 29                      Banking    2019        4915.01         3.0
# 30                       Export    2017        2740.45         1.0
# 31                    Marketing    2016         210.01         1.0
# 32                       Export    2016         360.01         1.0
# 33                       energy    2020        1142.10         3.0
# 34                       energy    2020       93204.21         2.0
# 35               sustainability    2020            NaN         5.0
# 36                    education    2020       50000.17         5.0
# 37             entrepreneurship    2015            NaN         1.0
# 38               sustainability    2020       45000.23         2.0
# 39             entrepreneurship    2020       22880.44         2.0
# 40            women empowerment    2017        8170.56         3.0
# 41               sustainability    2017      250000.22         3.0
# 42                     academia    2017        9657.11         1.0
# 43                social policy    2017            NaN         NaN
# 44                     politics    2016            NaN         NaN
# 45            women empowerment    2017            NaN         NaN
# 46               sustainability    2016            NaN         NaN
# 47                    education    2016            NaN         NaN
# 48               sustainability    2016            NaN         NaN
# 49                     academia    2016            NaN         NaN
# 50             entrepreneurship    2016            NaN         NaN
#
#        Fund_Cat  Grant
# 0   partnership      1
# 1     long-term      1
# 2     long-term      1
# 3     long-term      1
# 4     long-term      1
# 5   partnership      1
# 6   partnership      1
# 7   partnership      1
# 8   partnership      1
# 9   partnership      1
# 10     contract      1
# 11     contract      1
# 12     contract      1
# 13     contract      1
# 14    long-term      1
# 15    long-term      1
# 16     contract      1
# 17     contract      1
# 18    long-term      1
# 19     contract      1
# 20     contract      1
# 21    long-term      1
# 22     contract      1
# 23    long-term      1
# 24    long-term      1
# 25     contract      1
# 26    long-term      1
# 27   short-term      1
# 28   short-term      1
# 29  partnership      1
# 30   short-term      1
# 31   short-term      1
# 32   short-term      1
# 33    long-term      0
# 34    long-term      0
# 35    long-term      0
# 36    long-term      0
# 37    long-term      0
# 38   short-term      0
# 39   short-term      1
# 40    long-term      1
# 41    long-term      1
# 42   short-term      1
# 43   short-term      0
# 44   short-term      0
# 45   short-term      0
# 46   short-term      0
# 47   short-term      0
# 48   short-term      0
# 49   short-term      0
# 50   short-term      0

# %%
grant.head(5)
# Out:
#    GrantID                                            Grantor  \
# 0        1                       Sunref Nigeria & Access bank
# 1        2  Ford Foundation and Innocent Chukwuma Social I...
# 2        3                                    Ford Foundation
# 3        4                       Templeton Charity Foundation
# 4        5                                               Meta
#
#          Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl     Fund_Cat  Grant
# 0           energy    2022      312623.20         3.0  partnership      1
# 1   sustainability    2021     1000000.12         5.0    long-term      1
# 2   sustainability    2017       25400.45         5.0    long-term      1
# 3  virtual reality    2021      234000.12         5.0    long-term      1
# 4  virtual reality    2022      500000.45         5.0    long-term      1

# %%
grant.shape
# Out:
# (51, 8)

# %%
grant.columns #to check the columns or features
# Out:
# Index(['GrantID', 'Grantor', 'Rsch_Area', 'App_yr', 'Grant_Amt ($)',
#        'Project_Tl', 'Fund_Cat', 'Grant'],
#       dtype='object')

# %%
grant.isnull().sum() #to check for missing values
# Out:
# GrantID           0
# Grantor           0
# Rsch_Area         0
# App_yr            0
# Grant_Amt ($)    14
# Project_Tl        8
# Fund_Cat          0
# Grant             0
# dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %%
grant.isnull().sum() #to check for missing values
# Out:
# GrantID           0
# Grantor           0
# Rsch_Area         0
# App_yr            0
# Grant_Amt ($)    14
# Project_Tl        8
# Fund_Cat          0
# Grant             0
# dtype: int64

# %% [markdown]
# ### Handling missing values by replacement with means

# %%
grant['Project_Tl'].fillna(value = grant['Project_Tl'].mean()) # For project timeline column
# Out:
# 0      3.000000
# 1      5.000000
# 2      5.000000
# 3      5.000000
# 4      5.000000
# 5      5.000000
# 6      5.000000
# 7      1.000000
# 8      1.000000
# 9      1.000000
# 10     1.000000
# 11     1.000000
# 12     1.000000
# 13     1.000000
# 14    10.000000
# 15     6.000000
# 16     1.000000
# 17     1.000000
# 18     2.000000
# 19     1.000000
# 20     2.000000
# 21     2.000000
# 22     1.000000
# 23     1.000000
# 24     1.000000
# 25     1.000000
# 26     5.000000
# 27     1.000000
# 28     1.000000
# 29     3.000000
# 30     1.000000
# 31     1.000000
# 32     1.000000
# 33     3.000000
# 34     2.000000
# 35     5.000000
# 36     5.000000
# 37     1.000000
# 38     2.000000
# 39     2.000000
# 40     3.000000
# 41     3.000000
# 42     1.000000
# 43     2.534884
# 44     2.534884
# 45     2.534884
# 46     2.534884
# 47     2.534884
# 48     2.534884
# 49     2.534884
# 50     2.534884
# Name: Project_Tl, dtype: float64

# %% [markdown]
# ### Handling missing values by dropping - "Grant Amount" missing values

# %%
grant.dropna(axis =0, how="any", inplace=True)
grant.isna().sum()
# Out:
# GrantID          0
# Grantor          0
# Rsch_Area        0
# App_yr           0
# Grant_Amt ($)    0
# Project_Tl       0
# Fund_Cat         0
# Grant            0
# dtype: int64

# %% [markdown]
# # Features Engineering

# %%
grant_features = grant[['Rsch_Area', 'App_yr', 'Grant_Amt ($)','Project_Tl','Fund_Cat']]
grant_features
# Out:
#                       Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  \
# 0                        energy    2022      312623.20         3.0
# 1                sustainability    2021     1000000.12         5.0
# 2                sustainability    2017       25400.45         5.0
# 3               virtual reality    2021      234000.12         5.0
# 4               virtual reality    2022      500000.45         5.0
# 5              entrepreneurship    2022     1184834.23         5.0
# 6                sustainability    2021       71000.00         5.0
# 10            women empowerment    2022       40199.12         1.0
# 12            women empowerment    2022       54471.15         1.0
# 13  digital financial inclusion    2022       25764.56         1.0
# 14                     research    2018     1184834.44        10.0
# 15  digital financial inclusion    2017     6904650.56         6.0
# 16                       energy    2021        7693.21         1.0
# 17                       energy    2021       10977.37         1.0
# 18                       energy    2021       17881.88         2.0
# 19                       energy    2021        1930.00         1.0
# 20                       energy    2021       10977.21         2.0
# 21                     research    2021       10000.01         2.0
# 22                          art    2021        1826.01         1.0
# 23                          art    2021        7302.01         1.0
# 24                          art    2022        4810.02         1.0
# 25                          art    2022         609.11         1.0
# 26               sustainability    2016        9500.04         5.0
# 27                    Marketing    2017      161325.33         1.0
# 28                     Strategy    2018          70.12         1.0
# 29                      Banking    2019        4915.01         3.0
# 30                       Export    2017        2740.45         1.0
# 31                    Marketing    2016         210.01         1.0
# 32                       Export    2016         360.01         1.0
# 33                       energy    2020        1142.10         3.0
# 34                       energy    2020       93204.21         2.0
# 36                    education    2020       50000.17         5.0
# 38               sustainability    2020       45000.23         2.0
# 39             entrepreneurship    2020       22880.44         2.0
# 40            women empowerment    2017        8170.56         3.0
# 41               sustainability    2017      250000.22         3.0
# 42                     academia    2017        9657.11         1.0
#
#        Fund_Cat
# 0   partnership
# 1     long-term
# 2     long-term
# 3     long-term
# 4     long-term
# 5   partnership
# 6   partnership
# 10     contract
# 12     contract
# 13     contract
# 14    long-term
# 15    long-term
# 16     contract
# 17     contract
# 18    long-term
# 19     contract
# 20     contract
# 21    long-term
# 22     contract
# 23    long-term
# 24    long-term
# 25     contract
# 26    long-term
# 27   short-term
# 28   short-term
# 29  partnership
# 30   short-term
# 31   short-term
# 32   short-term
# 33    long-term
# 34    long-term
# 36    long-term
# 38   short-term
# 39   short-term
# 40    long-term
# 41    long-term
# 42   short-term

# %% [markdown]
# **Features Definitions**
#  - Rsch_Area = Research Area: subject of interest
#      - The grantors determine the subject matter such as women empowerment, sustainability, etc.
#  - App_yr = Application year: when the grant was secured.
#  - Grant_Amt  = Grant Amount secured  in DOLLAR.
#  - Project_Tl = Project timeline: time given to complete grant research.
#  - Fund_Cat = Funding Category: category of grant: short-term, long-term, partnership or contract.

# %%
from sklearn.preprocessing import LabelEncoder # importing the Scikit-learn package

# %%
LabelEncoder
# Out:
# sklearn.preprocessing._label.LabelEncoder

# %%
le = LabelEncoder() #initializing LabelEncoder

# %%
grant_features.columns
# Out:
# Index(['Rsch_Area', 'App_yr', 'Grant_Amt ($)', 'Project_Tl', 'Fund_Cat'], dtype='object')

# %% [markdown]
# ### Converting some features to numerical variables

# %%
le.fit_transform(grant_features['Rsch_Area']) # for research area
grant_features['Rsch_Area'] = le.fit_transform(grant_features['Rsch_Area'])
grant_features
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12800\4011331085.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grant_features['Rsch_Area'] = le.fit_transform(grant_features['Rsch_Area'])
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl     Fund_Cat
# 0           8       6      312623.20         3.0  partnership
# 1          11       5     1000000.12         5.0    long-term
# 2          11       1       25400.45         5.0    long-term
# 3          12       5      234000.12         5.0    long-term
# 4          12       6      500000.45         5.0    long-term
# 5           9       6     1184834.23         5.0  partnership
# 6          11       5       71000.00         5.0  partnership
# 10         13       6       40199.12         1.0     contract
# 12         13       6       54471.15         1.0     contract
# 13          6       6       25764.56         1.0     contract
# 14         10       2     1184834.44        10.0    long-term
# 15          6       1     6904650.56         6.0    long-term
# 16          8       5        7693.21         1.0     contract
# 17          8       5       10977.37         1.0     contract
# 18          8       5       17881.88         2.0    long-term
# 19          8       5        1930.00         1.0     contract
# 20          8       5       10977.21         2.0     contract
# 21         10       5       10000.01         2.0    long-term
# 22          5       5        1826.01         1.0     contract
# 23          5       5        7302.01         1.0    long-term
# 24          5       6        4810.02         1.0    long-term
# 25          5       6         609.11         1.0     contract
# 26         11       0        9500.04         5.0    long-term
# 27          2       1      161325.33         1.0   short-term
# 28          3       2          70.12         1.0   short-term
# 29          0       3        4915.01         3.0  partnership
# 30          1       1        2740.45         1.0   short-term
# 31          2       0         210.01         1.0   short-term
# 32          1       0         360.01         1.0   short-term
# 33          8       4        1142.10         3.0    long-term
# 34          8       4       93204.21         2.0    long-term
# 36          7       4       50000.17         5.0    long-term
# 38         11       4       45000.23         2.0   short-term
# 39          9       4       22880.44         2.0   short-term
# 40         13       1        8170.56         3.0    long-term
# 41         11       1      250000.22         3.0    long-term
# 42          4       1        9657.11         1.0   short-term

# %%
grant_features['Rsch_Area'].value_counts()
# Out:
# 8     8
# 11    6
# 5     4
# 13    3
# 12    2
# 9     2
# 6     2
# 10    2
# 2     2
# 1     2
# 3     1
# 0     1
# 7     1
# 4     1
# Name: Rsch_Area, dtype: int64

# %%
grant_features['App_yr'].value_counts()
# Out:
# 5    11
# 6     8
# 1     7
# 4     5
# 0     3
# 2     2
# 3     1
# Name: App_yr, dtype: int64

# %%
grant_features['Project_Tl'].value_counts()
# Out:
# 1.0     16
# 5.0      8
# 2.0      6
# 3.0      5
# 10.0     1
# 6.0      1
# Name: Project_Tl, dtype: int64

# %%
grant_features['Fund_Cat'].value_counts()
# Out:
# long-term      16
# contract        9
# short-term      8
# partnership     4
# Name: Fund_Cat, dtype: int64

# %%
grant_features['App_yr'] = le.fit_transform(grant_features['App_yr'])
grant_features
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12800\1274219505.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grant_features['App_yr'] = le.fit_transform(grant_features['App_yr'])
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl     Fund_Cat
# 0           8       6      312623.20         3.0  partnership
# 1          11       5     1000000.12         5.0    long-term
# 2          11       1       25400.45         5.0    long-term
# 3          12       5      234000.12         5.0    long-term
# 4          12       6      500000.45         5.0    long-term
# 5           9       6     1184834.23         5.0  partnership
# 6          11       5       71000.00         5.0  partnership
# 10         13       6       40199.12         1.0     contract
# 12         13       6       54471.15         1.0     contract
# 13          6       6       25764.56         1.0     contract
# 14         10       2     1184834.44        10.0    long-term
# 15          6       1     6904650.56         6.0    long-term
# 16          8       5        7693.21         1.0     contract
# 17          8       5       10977.37         1.0     contract
# 18          8       5       17881.88         2.0    long-term
# 19          8       5        1930.00         1.0     contract
# 20          8       5       10977.21         2.0     contract
# 21         10       5       10000.01         2.0    long-term
# 22          5       5        1826.01         1.0     contract
# 23          5       5        7302.01         1.0    long-term
# 24          5       6        4810.02         1.0    long-term
# 25          5       6         609.11         1.0     contract
# 26         11       0        9500.04         5.0    long-term
# 27          2       1      161325.33         1.0   short-term
# 28          3       2          70.12         1.0   short-term
# 29          0       3        4915.01         3.0  partnership
# 30          1       1        2740.45         1.0   short-term
# 31          2       0         210.01         1.0   short-term
# 32          1       0         360.01         1.0   short-term
# 33          8       4        1142.10         3.0    long-term
# 34          8       4       93204.21         2.0    long-term
# 36          7       4       50000.17         5.0    long-term
# 38         11       4       45000.23         2.0   short-term
# 39          9       4       22880.44         2.0   short-term
# 40         13       1        8170.56         3.0    long-term
# 41         11       1      250000.22         3.0    long-term
# 42          4       1        9657.11         1.0   short-term

# %%
grant_features['Fund_Cat'] = le.fit_transform(grant_features['Fund_Cat'])
grant_features
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_12800\1966653350.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grant_features['Fund_Cat'] = le.fit_transform(grant_features['Fund_Cat'])
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# 0           8       6      312623.20         3.0         2
# 1          11       5     1000000.12         5.0         1
# 2          11       1       25400.45         5.0         1
# 3          12       5      234000.12         5.0         1
# 4          12       6      500000.45         5.0         1
# 5           9       6     1184834.23         5.0         2
# 6          11       5       71000.00         5.0         2
# 10         13       6       40199.12         1.0         0
# 12         13       6       54471.15         1.0         0
# 13          6       6       25764.56         1.0         0
# 14         10       2     1184834.44        10.0         1
# 15          6       1     6904650.56         6.0         1
# 16          8       5        7693.21         1.0         0
# 17          8       5       10977.37         1.0         0
# 18          8       5       17881.88         2.0         1
# 19          8       5        1930.00         1.0         0
# 20          8       5       10977.21         2.0         0
# 21         10       5       10000.01         2.0         1
# 22          5       5        1826.01         1.0         0
# 23          5       5        7302.01         1.0         1
# 24          5       6        4810.02         1.0         1
# 25          5       6         609.11         1.0         0
# 26         11       0        9500.04         5.0         1
# 27          2       1      161325.33         1.0         3
# 28          3       2          70.12         1.0         3
# 29          0       3        4915.01         3.0         2
# 30          1       1        2740.45         1.0         3
# 31          2       0         210.01         1.0         3
# 32          1       0         360.01         1.0         3
# 33          8       4        1142.10         3.0         1
# 34          8       4       93204.21         2.0         1
# 36          7       4       50000.17         5.0         1
# 38         11       4       45000.23         2.0         3
# 39          9       4       22880.44         2.0         3
# 40         13       1        8170.56         3.0         1
# 41         11       1      250000.22         3.0         1
# 42          4       1        9657.11         1.0         3

# %% [markdown]
# --- the target variable (grant) recorded as coded: 1 for yes and 0 for no ---

# %%
grant_target = grant["Grant"]
grant_target
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     1
# 10    1
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    1
# 31    1
# 32    1
# 33    0
# 34    0
# 36    0
# 38    0
# 39    1
# 40    1
# 41    1
# 42    1
# Name: Grant, dtype: int64

# %% [markdown]
# ### BUILDING MODEL: Splitting the dataset into test data and train data for building model

# %%
from sklearn.model_selection import train_test_split

# %%
grant_features # to reconfirm the features (train data)
# Out:
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# 0           8       6      312623.20         3.0         2
# 1          11       5     1000000.12         5.0         1
# 2          11       1       25400.45         5.0         1
# 3          12       5      234000.12         5.0         1
# 4          12       6      500000.45         5.0         1
# 5           9       6     1184834.23         5.0         2
# 6          11       5       71000.00         5.0         2
# 10         13       6       40199.12         1.0         0
# 12         13       6       54471.15         1.0         0
# 13          6       6       25764.56         1.0         0
# 14         10       2     1184834.44        10.0         1
# 15          6       1     6904650.56         6.0         1
# 16          8       5        7693.21         1.0         0
# 17          8       5       10977.37         1.0         0
# 18          8       5       17881.88         2.0         1
# 19          8       5        1930.00         1.0         0
# 20          8       5       10977.21         2.0         0
# 21         10       5       10000.01         2.0         1
# 22          5       5        1826.01         1.0         0
# 23          5       5        7302.01         1.0         1
# 24          5       6        4810.02         1.0         1
# 25          5       6         609.11         1.0         0
# 26         11       0        9500.04         5.0         1
# 27          2       1      161325.33         1.0         3
# 28          3       2          70.12         1.0         3
# 29          0       3        4915.01         3.0         2
# 30          1       1        2740.45         1.0         3
# 31          2       0         210.01         1.0         3
# 32          1       0         360.01         1.0         3
# 33          8       4        1142.10         3.0         1
# 34          8       4       93204.21         2.0         1
# 36          7       4       50000.17         5.0         1
# 38         11       4       45000.23         2.0         3
# 39          9       4       22880.44         2.0         3
# 40         13       1        8170.56         3.0         1
# 41         11       1      250000.22         3.0         1
# 42          4       1        9657.11         1.0         3

# %%
grant_target # to confirm the target variable (test data)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     1
# 10    1
# 12    1
# 13    1
# 14    1
# 15    1
# 16    1
# 17    1
# 18    1
# 19    1
# 20    1
# 21    1
# 22    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    1
# 31    1
# 32    1
# 33    0
# 34    0
# 36    0
# 38    0
# 39    1
# 40    1
# 41    1
# 42    1
# Name: Grant, dtype: int64

# %%
feature_train, feature_test, target_train, target_test = train_test_split(grant_features, grant_target, test_size=0.2, random_state=0)  #assigning train and test data to each variable, also fixing the random state to zero to avoid reshuffling of accuracy score.

# %%
target_train
# Out:
# 2     1
# 29    1
# 34    0
# 38    0
# 42    1
# 40    1
# 33    0
# 39    1
# 12    1
# 17    1
# 5     1
# 21    1
# 18    1
# 10    1
# 31    1
# 1     1
# 16    1
# 30    1
# 28    1
# 6     1
# 27    1
# 4     1
# 22    1
# 25    1
# 23    1
# 13    1
# 41    1
# 3     1
# 0     1
# Name: Grant, dtype: int64

# %% [markdown]
# ### Using Support Vector Machine (SVM) for model binary classification

# %%
from sklearn.svm import SVC

# %%
classifier = SVC()

# %%
feature_train
# Out:
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# 2          11       1       25400.45         5.0         1
# 29          0       3        4915.01         3.0         2
# 34          8       4       93204.21         2.0         1
# 38         11       4       45000.23         2.0         3
# 42          4       1        9657.11         1.0         3
# 40         13       1        8170.56         3.0         1
# 33          8       4        1142.10         3.0         1
# 39          9       4       22880.44         2.0         3
# 12         13       6       54471.15         1.0         0
# 17          8       5       10977.37         1.0         0
# 5           9       6     1184834.23         5.0         2
# 21         10       5       10000.01         2.0         1
# 18          8       5       17881.88         2.0         1
# 10         13       6       40199.12         1.0         0
# 31          2       0         210.01         1.0         3
# 1          11       5     1000000.12         5.0         1
# 16          8       5        7693.21         1.0         0
# 30          1       1        2740.45         1.0         3
# 28          3       2          70.12         1.0         3
# 6          11       5       71000.00         5.0         2
# 27          2       1      161325.33         1.0         3
# 4          12       6      500000.45         5.0         1
# 22          5       5        1826.01         1.0         0
# 25          5       6         609.11         1.0         0
# 23          5       5        7302.01         1.0         1
# 13          6       6       25764.56         1.0         0
# 41         11       1      250000.22         3.0         1
# 3          12       5      234000.12         5.0         1
# 0           8       6      312623.20         3.0         2

# %%
target_train
# Out:
# 2     1
# 29    1
# 34    0
# 38    0
# 42    1
# 40    1
# 33    0
# 39    1
# 12    1
# 17    1
# 5     1
# 21    1
# 18    1
# 10    1
# 31    1
# 1     1
# 16    1
# 30    1
# 28    1
# 6     1
# 27    1
# 4     1
# 22    1
# 25    1
# 23    1
# 13    1
# 41    1
# 3     1
# 0     1
# Name: Grant, dtype: int64

# %%
model = classifier.fit(feature_train,target_train) # fitting the model

# %%
prediction = model.predict(feature_test) # making prediction

# %%
from sklearn.metrics import accuracy_score # using ACCURACY SCORE METRIC

# %%
accuracy_score(target_test, prediction)
# Out:
# 0.875

# %% [markdown]
# ### To further check the model performance, the confusion matrix can be used.

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(target_test, prediction))
# Out:
# [[0 1]
#  [0 7]]

# %% [markdown]
# #### Interpreting the _confusion matrix_ above:
# 1. The model classified NO likely as likely
# 2. classified 7 Unlikely as Unlikely
# 3. classified 1 Likely as Unlikely - type II error (false -ve)
# 4. classified No unlikely as likely - type I error (false +ve)
#
# __this shows a poor prediction power__ with _only 7 correct predictions, inspite of an accuracy of 87.5%_
# **Optionally, the model can be improved by dimensionality reduction or hyperparametrization!**

# %%
print(classification_report(target_test, prediction)) # precision report
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         1
#            1       0.88      1.00      0.93         7
#
#     accuracy                           0.88         8
#    macro avg       0.44      0.50      0.47         8
# weighted avg       0.77      0.88      0.82         8
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### Hyperparameterization

# %%
classifier = SVC()

# %%
classifier = SVC(kernel ='poly') #polynomial kernel

# %%
model = classifier.fit(feature_train,target_train)

# %%
prediction = model.predict(feature_test)

# %%
accuracy_score(target_test, prediction)
# Out:
# 0.875

# %% [markdown]
# **The model score is still 87.5%. This could be due to the randomization of my data proportions to 0, during data splitting.**

# %% [markdown]
# ## ALTENATIVELY: BUILDING A REGRESSION MODEL

# %%
grant_features
# Out:
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# 0           8       6      312623.20         3.0         2
# 1          11       5     1000000.12         5.0         1
# 2          11       1       25400.45         5.0         1
# 3          12       5      234000.12         5.0         1
# 4          12       6      500000.45         5.0         1
# 5           9       6     1184834.23         5.0         2
# 6          11       5       71000.00         5.0         2
# 10         13       6       40199.12         1.0         0
# 12         13       6       54471.15         1.0         0
# 13          6       6       25764.56         1.0         0
# 14         10       2     1184834.44        10.0         1
# 15          6       1     6904650.56         6.0         1
# 16          8       5        7693.21         1.0         0
# 17          8       5       10977.37         1.0         0
# 18          8       5       17881.88         2.0         1
# 19          8       5        1930.00         1.0         0
# 20          8       5       10977.21         2.0         0
# 21         10       5       10000.01         2.0         1
# 22          5       5        1826.01         1.0         0
# 23          5       5        7302.01         1.0         1
# 24          5       6        4810.02         1.0         1
# 25          5       6         609.11         1.0         0
# 26         11       0        9500.04         5.0         1
# 27          2       1      161325.33         1.0         3
# 28          3       2          70.12         1.0         3
# 29          0       3        4915.01         3.0         2
# 30          1       1        2740.45         1.0         3
# 31          2       0         210.01         1.0         3
# 32          1       0         360.01         1.0         3
# 33          8       4        1142.10         3.0         1
# 34          8       4       93204.21         2.0         1
# 36          7       4       50000.17         5.0         1
# 38         11       4       45000.23         2.0         3
# 39          9       4       22880.44         2.0         3
# 40         13       1        8170.56         3.0         1
# 41         11       1      250000.22         3.0         1
# 42          4       1        9657.11         1.0         3

# %%
x = grant_features # assigned the selected features to x, without the target variable, 'Grant'

# %%
x
# Out:
#     Rsch_Area  App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# 0           8       6      312623.20         3.0         2
# 1          11       5     1000000.12         5.0         1
# 2          11       1       25400.45         5.0         1
# 3          12       5      234000.12         5.0         1
# 4          12       6      500000.45         5.0         1
# 5           9       6     1184834.23         5.0         2
# 6          11       5       71000.00         5.0         2
# 10         13       6       40199.12         1.0         0
# 12         13       6       54471.15         1.0         0
# 13          6       6       25764.56         1.0         0
# 14         10       2     1184834.44        10.0         1
# 15          6       1     6904650.56         6.0         1
# 16          8       5        7693.21         1.0         0
# 17          8       5       10977.37         1.0         0
# 18          8       5       17881.88         2.0         1
# 19          8       5        1930.00         1.0         0
# 20          8       5       10977.21         2.0         0
# 21         10       5       10000.01         2.0         1
# 22          5       5        1826.01         1.0         0
# 23          5       5        7302.01         1.0         1
# 24          5       6        4810.02         1.0         1
# 25          5       6         609.11         1.0         0
# 26         11       0        9500.04         5.0         1
# 27          2       1      161325.33         1.0         3
# 28          3       2          70.12         1.0         3
# 29          0       3        4915.01         3.0         2
# 30          1       1        2740.45         1.0         3
# 31          2       0         210.01         1.0         3
# 32          1       0         360.01         1.0         3
# 33          8       4        1142.10         3.0         1
# 34          8       4       93204.21         2.0         1
# 36          7       4       50000.17         5.0         1
# 38         11       4       45000.23         2.0         3
# 39          9       4       22880.44         2.0         3
# 40         13       1        8170.56         3.0         1
# 41         11       1      250000.22         3.0         1
# 42          4       1        9657.11         1.0         3

# %%
y = grant_features["Rsch_Area"] # indexing research areas

# %% [markdown]
# **In research, it is believed that the research areas you are exploring determine your grant success**

# %%
y
# Out:
# 0      8
# 1     11
# 2     11
# 3     12
# 4     12
# 5      9
# 6     11
# 10    13
# 12    13
# 13     6
# 14    10
# 15     6
# 16     8
# 17     8
# 18     8
# 19     8
# 20     8
# 21    10
# 22     5
# 23     5
# 24     5
# 25     5
# 26    11
# 27     2
# 28     3
# 29     0
# 30     1
# 31     2
# 32     1
# 33     8
# 34     8
# 36     7
# 38    11
# 39     9
# 40    13
# 41    11
# 42     4
# Name: Rsch_Area, dtype: int64

# %%
x.corr() #checking for the assumption of multicollinearity via correlation
# Out:
#                Rsch_Area    App_yr  Grant_Amt ($)  Project_Tl  Fund_Cat
# Rsch_Area       1.000000  0.337713       0.003524    0.420169 -0.450155
# App_yr          0.337713  1.000000      -0.174092   -0.136583 -0.535625
# Grant_Amt ($)   0.003524 -0.174092       1.000000    0.442515 -0.039012
# Project_Tl      0.420169 -0.136583       0.442515    1.000000 -0.042527
# Fund_Cat       -0.450155 -0.535625      -0.039012   -0.042527  1.000000

# %% [markdown]
# _from the correlation matrix, Research area is positively correlated with most of other independent variables_

# %% [markdown]
# ### Building the model

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression #importing regression package

# %%
regressor = LinearRegression()

# %%
model = regressor.fit(x_train, y_train) # training the model

# %%
prediction = model.predict(x_test) # making prediction

# %%
Dictionary = {"Actual outcome": y_test, "Predicted outcome": prediction, "Error": y_test-prediction}

# %%
Dictionary
# Out:
# {'Actual outcome': 26    11
#  24     5
#  20     8
#  14    10
#  36     7
#  32     1
#  19     8
#  15     6
#  Name: Rsch_Area, dtype: int64,
#  'Predicted outcome': array([11.        ,  5.        ,  8.        ,  9.99999999,  7.        ,
#          1.        ,  8.        ,  5.99999995]),
#  'Error': 26   -1.062238e-09
#  24   -1.099976e-09
#  20   -1.050353e-09
#  14    8.395004e-09
#  36   -7.363568e-10
#  32   -1.135782e-09
#  19   -1.123151e-09
#  15    5.441908e-08
#  Name: Rsch_Area, dtype: float64}

# %%
pd.DataFrame(Dictionary) #adding the Dictionary of predicted and actual values into DataFrame
# Out:
#     Actual outcome  Predicted outcome         Error
# 26              11               11.0 -1.062238e-09
# 24               5                5.0 -1.099976e-09
# 20               8                8.0 -1.050353e-09
# 14              10               10.0  8.395004e-09
# 36               7                7.0 -7.363568e-10
# 32               1                1.0 -1.135782e-09
# 19               8                8.0 -1.123151e-09
# 15               6                6.0  5.441908e-08

# %% [markdown]
# ### Evaluating the regression model performance

# %%
from sklearn import metrics

# %%
pd.DataFrame(Dictionary) # Adding the prediction and actual outcomes into DataFrame
# Out:
#     Actual outcome  Predicted outcome         Error
# 26              11               11.0 -1.062238e-09
# 24               5                5.0 -1.099976e-09
# 20               8                8.0 -1.050353e-09
# 14              10               10.0  8.395004e-09
# 36               7                7.0 -7.363568e-10
# 32               1                1.0 -1.135782e-09
# 19               8                8.0 -1.123151e-09
# 15               6                6.0  5.441908e-08

# %%
metrics.r2_score(y_test, prediction)
# Out:
# 1.0

# %% [markdown]
# **This shows a perfect correlation between the dependent variable (Grant) and the independent variable (Research Area).**
#
# _It is to be noted that correlation does not imply causation._

# %% [markdown]
# ### SUMMARY
#
# - Both the Classification and Regression model can be used to predict the outcomes of grant application
#      - To increase research revenue in Lagos Business School, &
#      - To save application time and minimize risk of grant failure or rejection

# %% [markdown]
# **Chinonso Amamchukwu completed and submitted this end-to-end project on 22-Dec-2022**
